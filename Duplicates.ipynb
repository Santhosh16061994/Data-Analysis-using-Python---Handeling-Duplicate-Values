# %% [markdown]
# # Import libraries

# %%
import pandas as pd
import numpy as np

# %%
# Deal With Duplicate values
data = { 'RollNo':[1,2,3,4,1,1,5,2],
         'Name':['Ram','Raj','Tom','Raj','Ram','Ram','Tony','Raj'],
         'Marks':[10,20,30,40,10,10,40,20]
       }
df = pd.DataFrame(data)
df
# Out:
#    RollNo  Name  Marks
# 0       1   Ram     10
# 1       2   Raj     20
# 2       3   Tom     30
# 3       4   Raj     40
# 4       1   Ram     10
# 5       1   Ram     10
# 6       5  Tony     40
# 7       2   Raj     20

# %%
# Check for duplicate
df[df.duplicated()]
# df.duplicated()
# Out:
#    RollNo Name  Marks
# 4       1  Ram     10
# 5       1  Ram     10
# 7       2  Raj     20

# %%
# df.drop_duplicates(keep='first') #first,last
df.drop_duplicates(keep='last')
# df.drop_duplicates()
# Out:
#    RollNo  Name  Marks
# 2       3   Tom     30
# 3       4   Raj     40
# 5       1   Ram     10
# 6       5  Tony     40
# 7       2   Raj     20

# %%
np.unique(df.RollNo)
# Out:
# array([1, 2, 3, 4, 5])

# %%
#read the dataset
df=pd.read_csv('heart.csv')

# %%
df.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %%
df.tail()
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output
# 298    0      3       0
# 299    0      3       0
# 300    2      3       0
# 301    1      3       0
# 302    1      2       0

# %%
df.shape
# Out:
# (303, 14)

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# # Check for Duplicate value

# %%
df[df.duplicated()]
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 164   38    1   2     138   175    0        1       173     0      0.0    2
#
#      caa  thall  output
# 164    4      2       1

# %%
df.drop_duplicates(inplace=True)
df.reset_index(drop=True, inplace=True)
df.shape
# Out:
# (302, 14)

# %%
df.iloc[164:165,]
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 164   67    1   0     160   286    0        0       108     1      1.5    1
#
#      caa  thall  output
# 164    3      2       0

# %%
df
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 297   57    0   0     140   241    0        1       123     1      0.2    1
# 298   45    1   3     110   264    0        1       132     0      1.2    1
# 299   68    1   0     144   193    1        1       141     0      3.4    1
# 300   57    1   0     130   131    0        1       115     1      1.2    1
# 301   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output
# 0      0      1       1
# 1      0      2       1
# 2      0      2       1
# 3      0      2       1
# 4      0      2       1
# ..   ...    ...     ...
# 297    0      3       0
# 298    0      3       0
# 299    2      3       0
# 300    1      3       0
# 301    1      2       0
#
# [302 rows x 14 columns]
